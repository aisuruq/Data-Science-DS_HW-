# %%
# %run fastTemplateForlection3.ipynb
# Out:
# ...
# notebook ready to work!

# %%
# Load model directly
from transformers import TimeSeriesTransformerForPrediction

model = TimeSeriesTransformerForPrediction.from_pretrained("kleopatra102/air_pollution")

# %%
path = kagglehub.dataset_download("rohanrao/air-quality-data-in-india")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\aisur\.cache\kagglehub\datasets\rohanrao\air-quality-data-in-india\versions\12

# %%
path
# Out:
# 'C:\\Users\\aisur\\.cache\\kagglehub\\datasets\\rohanrao\\air-quality-data-in-india\\versions\\12'

# %%
import shutil 
data_path = './data'
shutil.move(path, data_path)
# Out:
# './data\\12'

# %%
from  pathlib import Path
path_to_data = Path( data_path + "/12/city_day.csv")

# %%
train_df = pd.read_csv(path_to_data)
val_df = pd.read_csv(path_to_data)

# %%
train_df.head()
# Out:
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN
